# %%
import pandas as pd
DATA=pd.read_csv('emissions_excel.txt',sep='\t')
DATA
# Out:
# <ipython-input-42-30a931ffa550>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   DATA=pd.read_csv('emissions_excel.txt',sep='\t')
#           airpol    cpa08 induse origin    unit   geo\time      2019  \
# 0            ACG  CPA_A01     P3    DOM  KG_HAB  EU27_2020      3.96
# 1            ACG  CPA_A01     P3    DOM  KG_HAB       EU28        :
# 2            ACG  CPA_A01     P3    DOM       T  EU27_2020   1769659
# 3            ACG  CPA_A01     P3    DOM       T       EU28        :
# 4            ACG  CPA_A01     P3    DOM   THS_T  EU27_2020  1769.659
# ...          ...      ...    ...    ...     ...        ...       ...
# 347323  SOX_SO2E   TOT_HH    TFU  WORLD  KG_HAB       EU28        :
# 347324  SOX_SO2E   TOT_HH    TFU  WORLD       T  EU27_2020   3524926
# 347325  SOX_SO2E   TOT_HH    TFU  WORLD       T       EU28        :
# 347326  SOX_SO2E   TOT_HH    TFU  WORLD   THS_T  EU27_2020  3524.926
# ...

# %%
EU27=DATA[DATA.loc[:,r'geo\time']=='EU27_2020'].drop(['2013','2012','2011','2010','2009','2008'], axis=1)
EU27
# Out:
#           airpol    cpa08 induse origin    unit   geo\time      2019  \
# 0            ACG  CPA_A01     P3    DOM  KG_HAB  EU27_2020      3.96
# 2            ACG  CPA_A01     P3    DOM       T  EU27_2020   1769659
# 4            ACG  CPA_A01     P3    DOM   THS_T  EU27_2020  1769.659
# 6            ACG  CPA_A01     P3    ROW  KG_HAB  EU27_2020     0.745
# 8            ACG  CPA_A01     P3    ROW       T  EU27_2020    332721
# ...          ...      ...    ...    ...     ...        ...       ...
# 347318  SOX_SO2E   TOT_HH    TFU    ROW       T  EU27_2020    683708
# 347320  SOX_SO2E   TOT_HH    TFU    ROW   THS_T  EU27_2020   683.708
# 347322  SOX_SO2E   TOT_HH    TFU  WORLD  KG_HAB  EU27_2020     7.888
# 347324  SOX_SO2E   TOT_HH    TFU  WORLD       T  EU27_2020   3524926
# 347326  SOX_SO2E   TOT_HH    TFU  WORLD   THS_T  EU27_2020  3524.926
#
#                2018         2017         2016         2015         2014
# ...

# %%
EU28=DATA[DATA.loc[:,r'geo\time']=='EU28'].drop(['2019'], axis=1)
EU28
# Out:
#           airpol    cpa08 induse origin    unit geo\time         2018  \
# 1            ACG  CPA_A01     P3    DOM  KG_HAB     EU28        3.952
# 3            ACG  CPA_A01     P3    DOM       T     EU28  2027709.000
# 5            ACG  CPA_A01     P3    DOM   THS_T     EU28     2027.709
# 7            ACG  CPA_A01     P3    ROW  KG_HAB     EU28        0.932
# 9            ACG  CPA_A01     P3    ROW       T     EU28   477994.000
# ...          ...      ...    ...    ...     ...      ...          ...
# 347319  SOX_SO2E   TOT_HH    TFU    ROW       T     EU28   813364.000
# 347321  SOX_SO2E   TOT_HH    TFU    ROW   THS_T     EU28      813.364
# 347323  SOX_SO2E   TOT_HH    TFU  WORLD  KG_HAB     EU28        7.610
# 347325  SOX_SO2E   TOT_HH    TFU  WORLD       T     EU28  3904382.000
# 347327  SOX_SO2E   TOT_HH    TFU  WORLD   THS_T     EU28     3904.382
#
#                2017         2016         2015         2014      2013  \
# ...

# %%
EU28.isna().sum()
# Out:
# airpol      0
# cpa08       0
# induse      0
# origin      0
# unit        0
# geo\time    0
# 2018        0
# 2017        0
# 2016        0
# 2015        0
# 2014        0
# 2013        0
# 2012        0
# 2011        0
# 2010        0
# 2009        0
# 2008        0
# dtype: int64

# %%
EU27.isna().sum()
# Out:
# airpol      0
# cpa08       0
# induse      0
# origin      0
# unit        0
# geo\time    0
# 2019        0
# 2018        0
# 2017        0
# 2016        0
# 2015        0
# 2014        0
# dtype: int64

# %%
EU28.to_csv(r"C:\\Users\diego\OneDrive\Desktop\DS\kaggle_datasets\emissions_greenhousegases_pollutants\emissions_EU28.csv",index=False)
EU27.to_csv(r"C:\\Users\diego\OneDrive\Desktop\DS\kaggle_datasets\emissions_greenhousegases_pollutants\emissions_EU27.csv",index=False)

# %%
#pd.read_csv(r"C:\\Users\diego\OneDrive\Desktop\DS\kaggle_datasets\emissions_greenhousegases_pollutants\emissions_EU28.csv")
#pd.read_csv(r"C:\\Users\diego\OneDrive\Desktop\DS\kaggle_datasets\emissions_greenhousegases_pollutants\emissions_EU27.csv")
# Out:
#           airpol    cpa08 induse origin    unit   geo\time         2019  \
# 0            ACG  CPA_A01     P3    DOM  KG_HAB  EU27_2020        3.960
# 1            ACG  CPA_A01     P3    DOM       T  EU27_2020  1769659.000
# 2            ACG  CPA_A01     P3    DOM   THS_T  EU27_2020     1769.659
# 3            ACG  CPA_A01     P3    ROW  KG_HAB  EU27_2020        0.745
# 4            ACG  CPA_A01     P3    ROW       T  EU27_2020   332721.000
# ...          ...      ...    ...    ...     ...        ...          ...
# 173659  SOX_SO2E   TOT_HH    TFU    ROW       T  EU27_2020   683708.000
# 173660  SOX_SO2E   TOT_HH    TFU    ROW   THS_T  EU27_2020      683.708
# 173661  SOX_SO2E   TOT_HH    TFU  WORLD  KG_HAB  EU27_2020        7.888
# 173662  SOX_SO2E   TOT_HH    TFU  WORLD       T  EU27_2020  3524926.000
# 173663  SOX_SO2E   TOT_HH    TFU  WORLD   THS_T  EU27_2020     3524.926
#
#                2018         2017         2016         2015         2014
# ...
